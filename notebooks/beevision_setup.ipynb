# %% [markdown]
# # BeeVision Setup
#
# This notebook checks Python/pip versions and installs dependencies for BeeVision.

# %%
# !python --version
# !pip --version

# %%
# !pip install --upgrade pip
# !pip install -q -r ../requirements.txt
